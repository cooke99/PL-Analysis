# %% [markdown]
# # Midfielder Player Analysis
#
# Which midfielders performed historically well over the last 3 seasons (2020/21 - 2022/23)? Well, it's complicated - players move around positions e.g. a player who was a forward and is now a midfielder such as Bryan Mbeumo. Obviously, the points earned by a player depend on their position - midfielders get 5 points for a goal whereas forwards get only 4. To overcome this, I will use 3 methods to rank the best 20 players from the last 3 seasons:
#
# * **Method 1:** Take this season's midfielders, and look at their average points over the last 3 seasons regardless of position. This is the "naive" method.
# * **Method 2:** Take this season's midfielders, and look at their average points over the last 3 seasons only if they also played as midfielders in those seasons. This is the "strict midfielders" approach.
# * **Method 3:** Take this season's midfielders, and map their stats over the last 3 seasons to the points they would've scored if they were a midfielder. This will require me to discard bonus points as these are scored differently per position and depend on the bps scored by all other players in the fixture. At this point, that is too complicated to account for.
#
# I will then compare the top 20 midfielders as measured by these methods (using their average total points - bonus points). Since we are discarding the bonus points, what matters here is the rank rather than the actual average points scored.
#
# Once I have compared the players generated by these methods, I will select the best 20 midfielders, and look at how their performance compares to this season so far (2023/24). I will carry out a one-sided t-test to see if there is a statistically significant difference in their performance, as well as look at the effect size to determine how big the difference is. I will then add information on their price this season, and the average rank of opposing teams. I will then export this information to an Excel file.
#
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import *
from statsmodels.stats.multitest import multipletests
from IPython.display import display_html
from IPython.display import HTML
from convert_points import convert_points

# %% [markdown]
# # Read and pre-process data
#
# ## 2023/24 data

# %%
path_2023_24 = '../data/Fantasy-Premier-League/data/2023-24/gws/merged_gw.csv'
data_2023_24 = pd.read_csv(path_2023_24, low_memory = False)
data_2023_24.loc[:,'total - bonus points'] = data_2023_24.total_points - data_2023_24.bonus
MIDs_2023_24 = data_2023_24.loc[data_2023_24.position == 'MID', 'name'].unique()
data_2023_24
# Out:
#                         name position            team   xP  assists  bonus  \
# 0                Femi Seriki      DEF   Sheffield Utd  0.5        0      0
# 1           Jack Hinshelwood      MID        Brighton  1.5        0      0
# 2               Jadon Sancho      MID         Man Utd  3.0        0      0
# 3     Rhys Norrington-Davies      DEF   Sheffield Utd  0.1        0      0
# 4              Vitaly Janelt      MID       Brentford  2.1        0      0
# ...                      ...      ...             ...  ...      ...    ...
# 2636             Kyle Walker      DEF        Man City  5.0        0      0
# 2637             Jacob Brown      FWD           Luton  1.2        0      0
# 2638          Vicente Guaita       GK  Crystal Palace  0.0        0      0
# 2639  Braian Ojeda Rodríguez      MID   Nott'm Forest  0.0        0      0
# 2640      Mads Bech Sørensen      DEF       Brentford  0.0        0      0
#
#       bps  clean_sheets  creativity  element  ...  threat  total_points  \
# 0       0             0         0.0      653  ...     0.0             0
# 1       0             0         0.0      621  ...     0.0             0
# 2       4             0        11.3      397  ...     8.0             1
# 3       0             0         0.0      487  ...     0.0             0
# 4       6             0        11.5      105  ...    17.0             2
# ...   ...           ...         ...      ...  ...     ...           ...
# 2636   14             0         5.5      369  ...     4.0             2
# 2637    2             0         0.0      631  ...     2.0             1
# 2638    0             0         0.0      227  ...     0.0             0
# 2639    0             0         0.0      459  ...     0.0             0
# 2640    0             0         0.0       93  ...     0.0             0
#
#       transfers_balance  transfers_in  transfers_out  value  was_home  \
# 0                     0             0              0     40      True
# 1                     0             0              0     45      True
# 2                     0             0              0     70      True
# 3                     0             0              0     40      True
# 4                     0             0              0     55      True
# ...                 ...           ...            ...    ...       ...
# 2636             245379        285979          40600     52      True
# 2637              -1785           625           2410     50      True
# 2638              -7875           660           8535     44      True
# 2639                -44             0             44     45     False
# 2640              -1159           474           1633     40      True
#
#       yellow_cards  GW total - bonus points
# 0                0   1                    0
# 1                0   1                    0
# 2                0   1                    1
# 3                0   1                    0
# 4                0   1                    2
# ...            ...  ..                  ...
# 2636             0   4                    2
# 2637             0   4                    1
# 2638             0   4                    0
# 2639             0   4                    0
# 2640             0   4                    0
#
# [2641 rows x 42 columns]

# %% [markdown]
# ## 2020/21 - 2022/23 data

# %%
data_2020_23_path = '../data/Fantasy-Premier-League/data/cleaned_merged_seasons.csv'
seasons_df = pd.read_csv(data_2020_23_path, low_memory = False)
seasons = ['2020-21', '2021-22', '2022-23']
data_2020_23_df = seasons_df.loc[seasons_df.season_x.isin(seasons),:]
data_2020_23_df.position = data_2020_23_df.position.map({'DEF':'DEF','FWD':'FWD','GK':'GK','GKP':'GK','MID':'MID'})
MIDs_2020_23_data = data_2020_23_df.loc[data_2020_23_df.name.isin(MIDs_2023_24),:]
MIDs_2020_23_data.loc[:,'total - bonus points'] = MIDs_2020_23_data.total_points - MIDs_2020_23_data.bonus
MIDs_2020_23_data
# Out:
# C:\Users\Development\AppData\Local\Temp\ipykernel_10056\2428986432.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020_23_df.position = data_2020_23_df.position.map({'DEF':'DEF','FWD':'FWD','GK':'GK','GKP':'GK','MID':'MID'})
# C:\Users\Development\AppData\Local\Temp\ipykernel_10056\2428986432.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MIDs_2020_23_data.loc[:,'total - bonus points'] = MIDs_2020_23_data.total_points - MIDs_2020_23_data.bonus
#       season_x                             name position       team_x  \
# 19856  2020-21               Abdoulaye Doucouré      MID      Everton
# 19858  2020-21                     Adama Traoré      MID       Wolves
# 19860  2020-21                     Adam Lallana      MID     Brighton
# 19869  2020-21              Alexis Mac Allister      MID     Brighton
# 19870  2020-21                       Alex Iwobi      MID      Everton
# ...        ...                              ...      ...          ...
# 96156  2022-23                     Reiss Nelson      MID      Arsenal
# 96157  2022-23  Gonçalo Manuel Ganchinho Guedes      MID       Wolves
# 96164  2022-23                     Oliver Skipp      MID        Spurs
# 96167  2022-23         Jeremy Sarmiento Morante      MID     Brighton
# 96168  2022-23                   Philip Billing      MID  Bournemouth
#
#        assists  bonus  bps  clean_sheets  creativity  element  ...  threat  \
# 19856        0      0   20             1        44.6      512  ...     4.0
# 19858        0      0    6             1         1.8      465  ...    17.0
# 19860        0      0    6             0        27.2       54  ...     2.0
# 19869        0      0    0             0         0.0       80  ...     0.0
# 19870        0      0    0             0         0.0      159  ...     0.0
# ...        ...    ...  ...           ...         ...      ...  ...     ...
# 96156        0      0    9             0         0.0       23  ...     0.0
# 96157        0      0    0             0         0.0      579  ...     0.0
# 96164        0      0   16             0         0.0      441  ...     0.0
# 96167        0      0    0             0         0.0      119  ...     0.0
# 96168        0      0   15             0         0.0       70  ...     0.0
#
#        total_points  transfers_balance  transfers_in  transfers_out value  \
# 19856             3                  0             0              0    55
# 19858             3                  0             0              0    65
# 19860             1                  0             0              0    65
# 19869             0                  0             0              0    55
# 19870             0                  0             0              0    60
# ...             ...                ...           ...            ...   ...
# 96156             1                468           747            279    47
# 96157             0                -27             0             27    58
# 96164             2                100           742            642    43
# 96167             0                -17            22             39    45
# 96168             2             -18361           736          19097    50
#
#        was_home  yellow_cards  GW  total - bonus points
# 19856     False             0   1                     3
# 19858     False             0   1                     3
# 19860      True             0   1                     1
# 19869      True             0   1                     0
# 19870     False             0   1                     0
# ...         ...           ...  ..                   ...
# 96156      True             0  38                     1
# 96157     False             0  38                     0
# 96164     False             0  38                     2
# 96167     False             0  38                     0
# 96168     False             0  38                     2
#
# [16344 rows x 38 columns]

# %% [markdown]
# # Method 1 (Naive)
#
# Look at this season's midfielders' historical performance over the last 3 years (2020/21 - 2022/23), regardless of the position they played in those seasons. This is the "naive" approach.
#
# ## Which players had the highest median score from 2020/21 - 2022/23?
#
# As seen in the points distributions per position plots, the total points scored by midfielders have a right skew. Outliers can inflate the mean compared to the median which is more robust.

# %%
top_20_MIDs_med = MIDs_2020_23_data.loc[:,['name','total_points', 'total - bonus points']].groupby(['name']).median()
top_20_MIDs_med.sort_values(by = 'total - bonus points', ascending = False, inplace = True)
top_20_MIDs_med = top_20_MIDs_med.iloc[0:20,:]
top_20_MIDs_med
# Out:
#                                      total_points  total - bonus points
# name
# Mohamed Salah                                 6.0                   6.0
# Gabriel Martinelli Silva                      4.5                   4.5
# Miguel Almirón Rejala                         3.0                   3.0
# Bukayo Saka                                   3.0                   3.0
# Bruno Borges Fernandes                        3.0                   3.0
# Solly March                                   2.5                   2.5
# Son Heung-min                                 2.5                   2.5
# Joelinton Cássio Apolinário de Lira           2.0                   2.0
# Eberechi Eze                                  2.0                   2.0
# Dwight McNeil                                 2.0                   2.0
# Douglas Luiz Soares de Paulo                  2.0                   2.0
# Abdoulaye Doucouré                            2.0                   2.0
# Joe Willock                                   2.0                   2.0
# Dango Ouattara                                2.0                   2.0
# Philip Billing                                2.0                   2.0
# Dejan Kulusevski                              2.0                   2.0
# Declan Rice                                   2.0                   2.0
# Raheem Sterling                               2.0                   2.0
# Remo Freuler                                  2.0                   2.0
# John Fleck                                    2.0                   2.0

# %% [markdown]
# ## Which players had the highest mean score from 2020/21 - 2022/23?

# %%
top_20_MIDs_mean = MIDs_2020_23_data.loc[:,['name','total_points', 'total - bonus points']].groupby(['name']).mean()
top_20_MIDs_mean.sort_values(by = 'total - bonus points', ascending = False, inplace = True)
top_20_MIDs_mean = top_20_MIDs_mean.iloc[0:20,:]
top_20_MIDs_mean
# Out:
#                           total_points  total - bonus points
# name
# Mohamed Salah                 6.447368              5.807018
# Gabriel Martinelli Silva      5.210526              4.736842
# Bruno Borges Fernandes        4.631579              4.026316
# Jarrod Bowen                  4.315789              3.956140
# Bukayo Saka                   4.342105              3.947368
# Kevin De Bruyne               4.561404              3.877193
# Son Heung-min                 4.000000              3.789474
# Miguel Almirón Rejala         4.157895              3.763158
# Martin Ødegaard               4.118280              3.666667
# Marcus Rashford               3.877193              3.614035
# James Maddison                3.938596              3.543860
# James Ward-Prowse             4.008772              3.517544
# Solly March                   3.868421              3.447368
# Leandro Trossard              3.745614              3.403509
# Raheem Sterling               3.666667              3.368421
# Kaoru Mitoma                  3.631579              3.342105
# Harvey Barnes                 3.517544              3.315789
# Phil Foden                    3.631579              3.254386
# Dejan Kulusevski              3.482143              3.250000
# Jack Harrison                 3.605263              3.236842

# %% [markdown]
# So we have a bit of a problem here, in that the median is quite a bit more informative than it was for the forwards, where the median was more or less the same for the top 15 players (besides Haaland and a few other exceptions). In that case, it was easy to justify our use of the mean. Here however, we have to think about things first. Our first question is whether the top 20 players as ranked by the median are the same as the top 20 ranked by the mean (irrespective of order).

# %%
set(top_20_MIDs_med.index) - set(top_20_MIDs_mean.index)
# Out:
# {'Abdoulaye Doucouré',
#  'Dango Ouattara',
#  'Declan Rice',
#  'Douglas Luiz Soares de Paulo',
#  'Dwight McNeil',
#  'Eberechi Eze',
#  'Joe Willock',
#  'Joelinton Cássio Apolinário de Lira',
#  'John Fleck',
#  'Philip Billing',
#  'Remo Freuler'}

# %% [markdown]
# Ok. So the answer is no - the top 20 are different for the median and mean. So let's take the union of both top 20s and compare the mean and median side by side.

# %%
top_20_mids_union = set(top_20_MIDs_med.index) | set(top_20_MIDs_mean.index)
top_20_mids_union
# Out:
# {'Abdoulaye Doucouré',
#  'Bruno Borges Fernandes',
#  'Bukayo Saka',
#  'Dango Ouattara',
#  'Declan Rice',
#  'Dejan Kulusevski',
#  'Douglas Luiz Soares de Paulo',
#  'Dwight McNeil',
#  'Eberechi Eze',
#  'Gabriel Martinelli Silva',
#  'Harvey Barnes',
#  'Jack Harrison',
#  'James Maddison',
#  'James Ward-Prowse',
#  'Jarrod Bowen',
#  'Joe Willock',
#  'Joelinton Cássio Apolinário de Lira',
#  'John Fleck',
#  'Kaoru Mitoma',
#  'Kevin De Bruyne',
#  'Leandro Trossard',
#  'Marcus Rashford',
#  'Martin Ødegaard',
#  'Miguel Almirón Rejala',
#  'Mohamed Salah',
#  'Phil Foden',
#  'Philip Billing',
#  'Raheem Sterling',
#  'Remo Freuler',
#  'Solly March',
#  'Son Heung-min'}

# %%
top_20_MIDs_mean_med = MIDs_2020_23_data.loc[MIDs_2020_23_data.name.isin(top_20_mids_union),
                                             ['name','total - bonus points']].groupby(['name']).agg(['mean','median'])
top_20_MIDs_mean_med.sort_values(by=('total - bonus points','mean'),ascending=False,inplace=True)
top_20_MIDs_mean_med
# Out:
#                                     total - bonus points
#                                                     mean median
# name
# Mohamed Salah                                   5.807018    6.0
# Gabriel Martinelli Silva                        4.736842    4.5
# Bruno Borges Fernandes                          4.026316    3.0
# Jarrod Bowen                                    3.956140    2.0
# Bukayo Saka                                     3.947368    3.0
# Kevin De Bruyne                                 3.877193    2.0
# Son Heung-min                                   3.789474    2.5
# Miguel Almirón Rejala                           3.763158    3.0
# Martin Ødegaard                                 3.666667    2.0
# Marcus Rashford                                 3.614035    2.0
# James Maddison                                  3.543860    2.0
# James Ward-Prowse                               3.517544    2.0
# Solly March                                     3.447368    2.5
# Leandro Trossard                                3.403509    2.0
# Raheem Sterling                                 3.368421    2.0
# Kaoru Mitoma                                    3.342105    2.0
# Harvey Barnes                                   3.315789    2.0
# Phil Foden                                      3.254386    2.0
# Dejan Kulusevski                                3.250000    2.0
# Jack Harrison                                   3.236842    2.0
# Philip Billing                                  2.947368    2.0
# Joe Willock                                     2.947368    2.0
# Dwight McNeil                                   2.631579    2.0
# Douglas Luiz Soares de Paulo                    2.482456    2.0
# Declan Rice                                     2.421053    2.0
# Eberechi Eze                                    2.412281    2.0
# Dango Ouattara                                  2.368421    2.0
# Joelinton Cássio Apolinário de Lira             2.192982    2.0
# Abdoulaye Doucouré                              1.982456    2.0
# John Fleck                                      1.815789    2.0
# Remo Freuler                                    1.500000    2.0

# %% [markdown]
# So, we can see from Trossard down that the median can not differentiate between players, and the mean is the only metric we can use. Indeed, from the original list, only 7 of the players had a median not equal to 2.0. Based on this, I am happy to take the top 20 players as ranked by the mean. But what do we do with these top 20 players? Do we sort them by median or mean? If we were to blindly apply the rules of a textbook then we'd rank by the median and carry on - as the points distribution for players are skewed by outliers. But we can be more intelligent than that. What do outliers represent in this context? Well, in the context of Fantasy Football, an outlier means a breakout performance: a player who normally only gets the 2 points for showing up has the game of his life and scores a goal or 2 or even 3. Or conversely, they have an absolute nightmare, and miss a penalty (-2 points) and get a yellow card for some argy bargy (-1 point). In this context, we care about these outliers, and we want to factor the information they contain into our analysis. It's important to know if a player has the capacity for the occasional breakout performance versus a player who's sole contribution is to spend 90 minutes on the pitch. So we will rank by the mean, but we will keep the median data for reference.

# %%
top_20_MIDs_mean_med = top_20_MIDs_mean_med.iloc[0:20]
top_20_MIDs_mean_med.columns = top_20_MIDs_mean_med.columns.to_flat_index()
top_20_MIDs_mean_med = top_20_MIDs_mean_med.rename(columns={('total - bonus points','mean'):'total - bonus pts mean', 
                                     ('total - bonus points','median'):'total - bonus pts median'})
top_20_MIDs_mean_med
# Out:
#                           total - bonus pts mean  total - bonus pts median
# name
# Mohamed Salah                           5.807018                       6.0
# Gabriel Martinelli Silva                4.736842                       4.5
# Bruno Borges Fernandes                  4.026316                       3.0
# Jarrod Bowen                            3.956140                       2.0
# Bukayo Saka                             3.947368                       3.0
# Kevin De Bruyne                         3.877193                       2.0
# Son Heung-min                           3.789474                       2.5
# Miguel Almirón Rejala                   3.763158                       3.0
# Martin Ødegaard                         3.666667                       2.0
# Marcus Rashford                         3.614035                       2.0
# James Maddison                          3.543860                       2.0
# James Ward-Prowse                       3.517544                       2.0
# Solly March                             3.447368                       2.5
# Leandro Trossard                        3.403509                       2.0
# Raheem Sterling                         3.368421                       2.0
# Kaoru Mitoma                            3.342105                       2.0
# Harvey Barnes                           3.315789                       2.0
# Phil Foden                              3.254386                       2.0
# Dejan Kulusevski                        3.250000                       2.0
# Jack Harrison                           3.236842                       2.0

# %%
top_20_MIDs_names = list(top_20_MIDs_mean_med.index)
top_20_MIDs_names
# Out:
# ['Mohamed Salah',
#  'Gabriel Martinelli Silva',
#  'Bruno Borges Fernandes',
#  'Jarrod Bowen',
#  'Bukayo Saka',
#  'Kevin De Bruyne',
#  'Son Heung-min',
#  'Miguel Almirón Rejala',
#  'Martin Ødegaard',
#  'Marcus Rashford',
#  'James Maddison',
#  'James Ward-Prowse',
#  'Solly March',
#  'Leandro Trossard',
#  'Raheem Sterling',
#  'Kaoru Mitoma',
#  'Harvey Barnes',
#  'Phil Foden',
#  'Dejan Kulusevski',
#  'Jack Harrison']

# %% [markdown]
# ##  How many matches did these players play?

# %%
matches_played = MIDs_2020_23_data.loc[:,['name','GW']].groupby('name').size()
matches_played = matches_played.loc[top_20_MIDs_names]
matches_played.name = 'GWs played'
top_20_MIDs_mean_med = top_20_MIDs_mean_med.join(matches_played)
top_20_MIDs_mean_med
# Out:
#                           total - bonus pts mean  total - bonus pts median  \
# name
# Mohamed Salah                           5.807018                       6.0
# Gabriel Martinelli Silva                4.736842                       4.5
# Bruno Borges Fernandes                  4.026316                       3.0
# Jarrod Bowen                            3.956140                       2.0
# Bukayo Saka                             3.947368                       3.0
# Kevin De Bruyne                         3.877193                       2.0
# Son Heung-min                           3.789474                       2.5
# Miguel Almirón Rejala                   3.763158                       3.0
# Martin Ødegaard                         3.666667                       2.0
# Marcus Rashford                         3.614035                       2.0
# James Maddison                          3.543860                       2.0
# James Ward-Prowse                       3.517544                       2.0
# Solly March                             3.447368                       2.5
# Leandro Trossard                        3.403509                       2.0
# Raheem Sterling                         3.368421                       2.0
# Kaoru Mitoma                            3.342105                       2.0
# Harvey Barnes                           3.315789                       2.0
# Phil Foden                              3.254386                       2.0
# Dejan Kulusevski                        3.250000                       2.0
# Jack Harrison                           3.236842                       2.0
#
#                           GWs played
# name
# Mohamed Salah                    114
# Gabriel Martinelli Silva          38
# Bruno Borges Fernandes            38
# Jarrod Bowen                     114
# Bukayo Saka                      114
# Kevin De Bruyne                  114
# Son Heung-min                     38
# Miguel Almirón Rejala             38
# Martin Ødegaard                   93
# Marcus Rashford                  114
# James Maddison                   114
# James Ward-Prowse                114
# Solly March                       38
# Leandro Trossard                 114
# Raheem Sterling                  114
# Kaoru Mitoma                      38
# Harvey Barnes                    114
# Phil Foden                       114
# Dejan Kulusevski                  56
# Jack Harrison                    114

# %% [markdown]
# ## Extract points data for each of these players and generate boxplots:

# %%
points_data = []
for name in top_20_MIDs_names:
    points_data.append(MIDs_2020_23_data.loc[MIDs_2020_23_data.name == name,'total - bonus points'].values.astype(float))

# %%
title_font = 18
axis_title_font = 16
legend_font = 14
axis_label_font = 14
axis_tick_font = 11

fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (10,7))
box_dict = ax.boxplot(points_data, whis=(5,95), labels = top_20_MIDs_names, meanline = True, showmeans = True)
_ = ax.set_xticklabels(ax.get_xticklabels(), fontsize = axis_tick_font, rotation = 45)
_ = ax.set_yticks(np.arange(-2,24,2))
_ = ax.set_yticklabels(ax.get_yticklabels(), fontsize = axis_tick_font)
ax.set_ylabel('Total points - bonus points', fontsize = axis_label_font)
ax.grid(axis = 'y', alpha = 0.3)
ax.legend([box_dict['medians'][0], box_dict['means'][0]], ['median', 'mean'], fontsize = legend_font)
ax.set_title('''Box plots of top 20 midfielders' points, 2020/21 - 2022/23''', fontsize = axis_title_font)
fig.tight_layout(pad=1.0)
plt.savefig('./plots/top_20_MIDs_boxplots.png', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Method 1 Summary Results
#
# We won't look at how these points are scored yet, because again that depends on position.
# So, overall, the best 20 players ranked by their total - bonus points irrespective of position is:

# %%
method_1_results = top_20_MIDs_mean_med.copy()
method_1_results
# Out:
#                           total - bonus pts mean  total - bonus pts median  \
# name
# Mohamed Salah                           5.807018                       6.0
# Gabriel Martinelli Silva                4.736842                       4.5
# Bruno Borges Fernandes                  4.026316                       3.0
# Jarrod Bowen                            3.956140                       2.0
# Bukayo Saka                             3.947368                       3.0
# Kevin De Bruyne                         3.877193                       2.0
# Son Heung-min                           3.789474                       2.5
# Miguel Almirón Rejala                   3.763158                       3.0
# Martin Ødegaard                         3.666667                       2.0
# Marcus Rashford                         3.614035                       2.0
# James Maddison                          3.543860                       2.0
# James Ward-Prowse                       3.517544                       2.0
# Solly March                             3.447368                       2.5
# Leandro Trossard                        3.403509                       2.0
# Raheem Sterling                         3.368421                       2.0
# Kaoru Mitoma                            3.342105                       2.0
# Harvey Barnes                           3.315789                       2.0
# Phil Foden                              3.254386                       2.0
# Dejan Kulusevski                        3.250000                       2.0
# Jack Harrison                           3.236842                       2.0
#
#                           GWs played
# name
# Mohamed Salah                    114
# Gabriel Martinelli Silva          38
# Bruno Borges Fernandes            38
# Jarrod Bowen                     114
# Bukayo Saka                      114
# Kevin De Bruyne                  114
# Son Heung-min                     38
# Miguel Almirón Rejala             38
# Martin Ødegaard                   93
# Marcus Rashford                  114
# James Maddison                   114
# James Ward-Prowse                114
# Solly March                       38
# Leandro Trossard                 114
# Raheem Sterling                  114
# Kaoru Mitoma                      38
# Harvey Barnes                    114
# Phil Foden                       114
# Dejan Kulusevski                  56
# Jack Harrison                    114

# %% [markdown]
# # Method 2 (Strict Forwards)
#
# Select only players that are forwards this season and played as forwards in the last 3 seasons.

# %%
strict_FWDs = FWDs_2020_23_data.loc[FWDs_2020_23_data.position == 'FWD', :]
strict_FWDs
# Out:
#       season_x                   name position          team_x  assists  \
# 19852  2020-21         Aaron Connolly      FWD        Brighton        0
# 19867  2020-21    Aleksandar Mitrović      FWD          Fulham        0
# 19912  2020-21          Callum Wilson      FWD       Newcastle        0
# 19938  2020-21             Danny Ings      FWD     Southampton        0
# 19958  2020-21  Dominic Calvert-Lewin      FWD         Everton        0
# ...        ...                    ...      ...             ...      ...
# 96106  2022-23             Danny Ings      FWD        West Ham        1
# 96115  2022-23        Odsonne Edouard      FWD  Crystal Palace        0
# 96123  2022-23            Deniz Undav      FWD        Brighton        0
# 96134  2022-23             Jhon Durán      FWD     Aston Villa        0
# 96160  2022-23          Thomas Cannon      FWD         Everton        0
#
#        bonus  bps  clean_sheets  creativity  element  ...  threat  \
# 19852      0   -3             0         0.3       78  ...    32.0
# 19867      0    3             0         0.3      184  ...     7.0
# 19912      2   32             1        23.3      506  ...    50.0
# 19938      0    1             0        11.2      366  ...    60.0
# 19958      2   34             1        13.7      164  ...    34.0
# ...      ...  ...           ...         ...      ...  ...     ...
# 96106      0    3             0         0.0       30  ...     0.0
# 96115      0    4             0         0.0      166  ...     0.0
# 96123      0   23             0         0.0      123  ...     0.0
# 96134      0    0             0         0.0      711  ...     0.0
# 96160      0    0             0         0.0      662  ...     0.0
#
#        total_points  transfers_balance  transfers_in  transfers_out value  \
# 19852             1                  0             0              0    55
# 19867             1                  0             0              0    60
# 19912             8                  0             0              0    65
# 19938             2                  0             0              0    85
# 19958             8                  0             0              0    70
# ...             ...                ...           ...            ...   ...
# 96106             3               1118          4009           2891    63
# 96115             2              12844         18089           5245    50
# 96123             5             -13569          4263          17832    50
# 96134             0               -126           174            300    55
# 96160             0                -17             0             17    45
#
#        was_home  yellow_cards  GW  total - bonus points
# 19852      True             0   1                     1
# 19867      True             0   1                     1
# 19912     False             0   1                     6
# 19938     False             0   1                     2
# 19958     False             0   1                     6
# ...         ...           ...  ..                   ...
# 96106     False             1  38                     3
# 96115      True             0  38                     2
# 96123     False             1  38                     5
# 96134      True             0  38                     0
# 96160      True             0  38                     0
#
# [3729 rows x 38 columns]

# %% [markdown]
# ## Which players had the highest mean score from 2020/21 to 2022/23?

# %%
top_15_FWDs_mean = strict_FWDs.loc[:,['name','total_points', 'total - bonus points']].groupby(['name']).mean()
top_15_FWDs_mean.sort_values(by = 'total - bonus points', ascending = False, inplace = True)
top_15_FWDs_mean = top_15_FWDs_mean.iloc[0:15,:]
top_15_FWDs_mean
# Out:
#                            total_points  total - bonus points
# name
# Erling Haaland                 7.157895              6.105263
# Harry Kane                     6.114035              5.140351
# Ollie Watkins                  4.157895              3.631579
# Ivan Toney                     4.223684              3.513158
# Dominic Solanke                3.421053              3.052632
# Daniel Jebbison                3.000000              2.750000
# Gabriel Fernando de Jesus      3.157895              2.728070
# Callum Wilson                  3.210526              2.719298
# Michail Antonio                3.000000              2.675439
# Danny Ings                     2.929825              2.526316
# Darwin Núñez Ribeiro           2.631579              2.421053
# Alexander Isak                 2.857143              2.342857
# Julián Álvarez                 2.710526              2.342105
# Chris Wood                     2.517857              2.241071
# Taiwo Awoniyi                  2.631579              2.210526

# %%
top_15_FWD_names = list(top_15_FWDs_mean.index)
top_15_FWD_names
# Out:
# ['Erling Haaland',
#  'Harry Kane',
#  'Ollie Watkins',
#  'Ivan Toney',
#  'Dominic Solanke',
#  'Daniel Jebbison',
#  'Gabriel Fernando de Jesus',
#  'Callum Wilson',
#  'Michail Antonio',
#  'Danny Ings',
#  'Darwin Núñez Ribeiro',
#  'Alexander Isak',
#  'Julián Álvarez',
#  'Chris Wood',
#  'Taiwo Awoniyi']

# %% [markdown]
# ## How many GWs did they play?

# %%
matches_played = strict_FWDs.loc[:,['name','GW']].groupby('name').size()
matches_played = matches_played.loc[top_15_FWD_names]
matches_played.name = 'GWs played'
top_15_FWDs_mean = top_15_FWDs_mean.join(matches_played)
top_15_FWDs_mean
# Out:
#                            total_points  total - bonus points  GWs played
# name
# Erling Haaland                 7.157895              6.105263          38
# Harry Kane                     6.114035              5.140351         114
# Ollie Watkins                  4.157895              3.631579         114
# Ivan Toney                     4.223684              3.513158          76
# Dominic Solanke                3.421053              3.052632          38
# Daniel Jebbison                3.000000              2.750000           4
# Gabriel Fernando de Jesus      3.157895              2.728070         114
# Callum Wilson                  3.210526              2.719298         114
# Michail Antonio                3.000000              2.675439         114
# Danny Ings                     2.929825              2.526316         114
# Darwin Núñez Ribeiro           2.631579              2.421053          38
# Alexander Isak                 2.857143              2.342857          35
# Julián Álvarez                 2.710526              2.342105          38
# Chris Wood                     2.517857              2.241071         112
# Taiwo Awoniyi                  2.631579              2.210526          38

# %% [markdown]
# ## Method 2 Summary Results

# %%
method_2_results = top_15_FWDs_mean.copy()
method_2_results
# Out:
#                            total_points  total - bonus points  GWs played
# name
# Erling Haaland                 7.157895              6.105263          38
# Harry Kane                     6.114035              5.140351         114
# Ollie Watkins                  4.157895              3.631579         114
# Ivan Toney                     4.223684              3.513158          76
# Dominic Solanke                3.421053              3.052632          38
# Daniel Jebbison                3.000000              2.750000           4
# Gabriel Fernando de Jesus      3.157895              2.728070         114
# Callum Wilson                  3.210526              2.719298         114
# Michail Antonio                3.000000              2.675439         114
# Danny Ings                     2.929825              2.526316         114
# Darwin Núñez Ribeiro           2.631579              2.421053          38
# Alexander Isak                 2.857143              2.342857          35
# Julián Álvarez                 2.710526              2.342105          38
# Chris Wood                     2.517857              2.241071         112
# Taiwo Awoniyi                  2.631579              2.210526          38

# %% [markdown]
# # Method 3 (Points map)
#
# Map the stats from all of this season's forwards from 2020 - 2023 to the points they would've scored if they were a forward. Sum across the columns to get total - bonus points.
#
# ## Re-map the points

# %%
Remap_FWDs_2020_2023 = FWDs_2020_23_data.loc[:, ['name', 'minutes', 'goals_scored', 'assists', 'clean_sheets', 'saves',
                          'penalties_saved', 'penalties_missed', 'goals_conceded', 'yellow_cards',
                          'red_cards', 'own_goals']]
Remap_FWDs_2020_2023 = convert_points('FWD', Remap_FWDs_2020_2023)
Remap_FWDs_2020_2023['total - bonus points'] =  Remap_FWDs_2020_2023.drop(columns=['name']).sum(axis=1)
Remap_FWDs_2020_2023
# Out:
#                         name  minutes  goals_scored  assists  clean_sheets  \
# 19852         Aaron Connolly        1             0        0             0
# 19867    Aleksandar Mitrović        1             0        0             0
# 19912          Callum Wilson        2             4        0             0
# 19938             Danny Ings        2             0        0             0
# 19958  Dominic Calvert-Lewin        2             4        0             0
# ...                      ...      ...           ...      ...           ...
# 96106             Danny Ings        1             0        3             0
# 96115        Odsonne Edouard        2             0        0             0
# 96123            Deniz Undav        2             4        0             0
# 96134             Jhon Durán        0             0        0             0
# 96160          Thomas Cannon        0             0        0             0
#
#        saves  penalties_saved  penalties_missed  goals_conceded  yellow_cards  \
# 19852      0                0                 0               0             0
# 19867      0                0                 0               0             0
# 19912      0                0                 0               0             0
# 19938      0                0                 0               0             0
# 19958      0                0                 0               0             0
# ...      ...              ...               ...             ...           ...
# 96106      0                0                 0               0            -1
# 96115      0                0                 0               0             0
# 96123      0                0                 0               0            -1
# 96134      0                0                 0               0             0
# 96160      0                0                 0               0             0
#
#        red_cards  own_goals  total - bonus points
# 19852          0          0                     1
# 19867          0          0                     1
# 19912          0          0                     6
# 19938          0          0                     2
# 19958          0          0                     6
# ...          ...        ...                   ...
# 96106          0          0                     3
# 96115          0          0                     2
# 96123          0          0                     5
# 96134          0          0                     0
# 96160          0          0                     0
#
# [3901 rows x 13 columns]

# %% [markdown]
# ## Which players had the highest mean points after the remapping?

# %%
top_15_FWDs_mean = Remap_FWDs_2020_2023.loc[:,['name','total - bonus points']].groupby(['name']).mean()
top_15_FWDs_mean.sort_values(by = 'total - bonus points', ascending = False, inplace = True)
top_15_FWDs_mean = top_15_FWDs_mean.iloc[0:15,:]
top_15_FWDs_mean
# Out:
#                            total - bonus points
# name
# Erling Haaland                         6.105263
# Harry Kane                             5.140351
# Ollie Watkins                          3.631579
# Ivan Toney                             3.513158
# Cody Gakpo                             3.318182
# Dominic Solanke                        3.052632
# Daniel Jebbison                        2.750000
# Gabriel Fernando de Jesus              2.728070
# Callum Wilson                          2.719298
# Michail Antonio                        2.675439
# Danny Ings                             2.526316
# Darwin Núñez Ribeiro                   2.421053
# Alexander Isak                         2.342857
# Julián Álvarez                         2.342105
# Chris Wood                             2.241071

# %%
top_15_FWD_names = list(top_15_FWDs_mean.index)
top_15_FWD_names
# Out:
# ['Erling Haaland',
#  'Harry Kane',
#  'Ollie Watkins',
#  'Ivan Toney',
#  'Cody Gakpo',
#  'Dominic Solanke',
#  'Daniel Jebbison',
#  'Gabriel Fernando de Jesus',
#  'Callum Wilson',
#  'Michail Antonio',
#  'Danny Ings',
#  'Darwin Núñez Ribeiro',
#  'Alexander Isak',
#  'Julián Álvarez',
#  'Chris Wood']

# %% [markdown]
# ## How many games did they play?

# %%
matches_played = FWDs_2020_23_data.loc[:,['name','GW']].groupby('name').size()
matches_played = matches_played.loc[top_15_FWD_names]
matches_played.name = 'GWs played'
top_15_FWDs_mean = top_15_FWDs_mean.join(matches_played)
top_15_FWDs_mean
# Out:
#                            total - bonus points  GWs played
# name
# Erling Haaland                         6.105263          38
# Harry Kane                             5.140351         114
# Ollie Watkins                          3.631579         114
# Ivan Toney                             3.513158          76
# Cody Gakpo                             3.318182          22
# Dominic Solanke                        3.052632          38
# Daniel Jebbison                        2.750000           4
# Gabriel Fernando de Jesus              2.728070         114
# Callum Wilson                          2.719298         114
# Michail Antonio                        2.675439         114
# Danny Ings                             2.526316         114
# Darwin Núñez Ribeiro                   2.421053          38
# Alexander Isak                         2.342857          35
# Julián Álvarez                         2.342105          38
# Chris Wood                             2.241071         112

# %% [markdown]
# ## Method 3 Summary Results

# %%
method_3_results = top_15_FWDs_mean.copy()
method_3_results
# Out:
#                            total - bonus points  GWs played
# name
# Erling Haaland                         6.105263          38
# Harry Kane                             5.140351         114
# Ollie Watkins                          3.631579         114
# Ivan Toney                             3.513158          76
# Cody Gakpo                             3.318182          22
# Dominic Solanke                        3.052632          38
# Daniel Jebbison                        2.750000           4
# Gabriel Fernando de Jesus              2.728070         114
# Callum Wilson                          2.719298         114
# Michail Antonio                        2.675439         114
# Danny Ings                             2.526316         114
# Darwin Núñez Ribeiro                   2.421053          38
# Alexander Isak                         2.342857          35
# Julián Álvarez                         2.342105          38
# Chris Wood                             2.241071         112

# %% [markdown]
# # How do the results from the 3 methods compare?

# %%
# Set up HTML styles to display tables side-by-side
method_1_results = method_1_results.drop(columns=['total_points'])
method_2_results = method_2_results.drop(columns=['total_points'])
styles = [dict(selector="caption",props=[("font-size", "175%")])]
method_1_styler = method_1_results.style.set_table_attributes("style='display:inline'").set_caption('Method 1 (Naive)').set_table_styles(styles)
method_2_styler = method_2_results.style.set_table_attributes("style='display:inline'").set_caption('Method 2 (Strict FWDs)').set_table_styles(styles)
method_3_styler = method_3_results.style.set_table_attributes("style='display:inline'").set_caption('Method 3 (Remap pts)').set_table_styles(styles)
display_html(method_1_styler._repr_html_()+method_2_styler._repr_html_()+method_3_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# #T_8db00 caption {
#   font-size: 175%;
# }
# </style>
# <table id="T_8db00" style='display:inline'>
#   <caption>Method 1 (Naive)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8db00_level0_col0" class="col_heading level0 col0" >total - bonus points</th>
#       <th id="T_8db00_level0_col1" class="col_heading level0 col1" >GWs played</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8db00_level0_row0" class="row_heading level0 row0" >Erling Haaland</th>
#       <td id="T_8db00_row0_col0" class="data row0 col0" >6.105263</td>
#       <td id="T_8db00_row0_col1" class="data row0 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row1" class="row_heading level0 row1" >Harry Kane</th>
#       <td id="T_8db00_row1_col0" class="data row1 col0" >5.140351</td>
#       <td id="T_8db00_row1_col1" class="data row1 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row2" class="row_heading level0 row2" >Cody Gakpo</th>
#       <td id="T_8db00_row2_col0" class="data row2 col0" >3.909091</td>
#       <td id="T_8db00_row2_col1" class="data row2 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row3" class="row_heading level0 row3" >Ollie Watkins</th>
#       <td id="T_8db00_row3_col0" class="data row3 col0" >3.631579</td>
#       <td id="T_8db00_row3_col1" class="data row3 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row4" class="row_heading level0 row4" >Ivan Toney</th>
#       <td id="T_8db00_row4_col0" class="data row4 col0" >3.513158</td>
#       <td id="T_8db00_row4_col1" class="data row4 col1" >76</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row5" class="row_heading level0 row5" >Dominic Solanke</th>
#       <td id="T_8db00_row5_col0" class="data row5 col0" >3.052632</td>
#       <td id="T_8db00_row5_col1" class="data row5 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row6" class="row_heading level0 row6" >Daniel Jebbison</th>
#       <td id="T_8db00_row6_col0" class="data row6 col0" >2.750000</td>
#       <td id="T_8db00_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row7" class="row_heading level0 row7" >Gabriel Fernando de Jesus</th>
#       <td id="T_8db00_row7_col0" class="data row7 col0" >2.728070</td>
#       <td id="T_8db00_row7_col1" class="data row7 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row8" class="row_heading level0 row8" >Callum Wilson</th>
#       <td id="T_8db00_row8_col0" class="data row8 col0" >2.719298</td>
#       <td id="T_8db00_row8_col1" class="data row8 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row9" class="row_heading level0 row9" >Michail Antonio</th>
#       <td id="T_8db00_row9_col0" class="data row9 col0" >2.675439</td>
#       <td id="T_8db00_row9_col1" class="data row9 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row10" class="row_heading level0 row10" >Danny Ings</th>
#       <td id="T_8db00_row10_col0" class="data row10 col0" >2.526316</td>
#       <td id="T_8db00_row10_col1" class="data row10 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row11" class="row_heading level0 row11" >Yoane Wissa</th>
#       <td id="T_8db00_row11_col0" class="data row11 col0" >2.513158</td>
#       <td id="T_8db00_row11_col1" class="data row11 col1" >76</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row12" class="row_heading level0 row12" >Darwin Núñez Ribeiro</th>
#       <td id="T_8db00_row12_col0" class="data row12 col0" >2.421053</td>
#       <td id="T_8db00_row12_col1" class="data row12 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row13" class="row_heading level0 row13" >Alexander Isak</th>
#       <td id="T_8db00_row13_col0" class="data row13 col0" >2.342857</td>
#       <td id="T_8db00_row13_col1" class="data row13 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_8db00_level0_row14" class="row_heading level0 row14" >Julián Álvarez</th>
#       <td id="T_8db00_row14_col0" class="data row14 col0" >2.342105</td>
#       <td id="T_8db00_row14_col1" class="data row14 col1" >38</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_19e2e caption {
#   font-size: 175%;
# }
# </style>
# <table id="T_19e2e" style='display:inline'>
#   <caption>Method 2 (Strict FWDs)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19e2e_level0_col0" class="col_heading level0 col0" >total - bonus points</th>
#       <th id="T_19e2e_level0_col1" class="col_heading level0 col1" >GWs played</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19e2e_level0_row0" class="row_heading level0 row0" >Erling Haaland</th>
#       <td id="T_19e2e_row0_col0" class="data row0 col0" >6.105263</td>
#       <td id="T_19e2e_row0_col1" class="data row0 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row1" class="row_heading level0 row1" >Harry Kane</th>
#       <td id="T_19e2e_row1_col0" class="data row1 col0" >5.140351</td>
#       <td id="T_19e2e_row1_col1" class="data row1 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row2" class="row_heading level0 row2" >Ollie Watkins</th>
#       <td id="T_19e2e_row2_col0" class="data row2 col0" >3.631579</td>
#       <td id="T_19e2e_row2_col1" class="data row2 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row3" class="row_heading level0 row3" >Ivan Toney</th>
#       <td id="T_19e2e_row3_col0" class="data row3 col0" >3.513158</td>
#       <td id="T_19e2e_row3_col1" class="data row3 col1" >76</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row4" class="row_heading level0 row4" >Dominic Solanke</th>
#       <td id="T_19e2e_row4_col0" class="data row4 col0" >3.052632</td>
#       <td id="T_19e2e_row4_col1" class="data row4 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row5" class="row_heading level0 row5" >Daniel Jebbison</th>
#       <td id="T_19e2e_row5_col0" class="data row5 col0" >2.750000</td>
#       <td id="T_19e2e_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row6" class="row_heading level0 row6" >Gabriel Fernando de Jesus</th>
#       <td id="T_19e2e_row6_col0" class="data row6 col0" >2.728070</td>
#       <td id="T_19e2e_row6_col1" class="data row6 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row7" class="row_heading level0 row7" >Callum Wilson</th>
#       <td id="T_19e2e_row7_col0" class="data row7 col0" >2.719298</td>
#       <td id="T_19e2e_row7_col1" class="data row7 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row8" class="row_heading level0 row8" >Michail Antonio</th>
#       <td id="T_19e2e_row8_col0" class="data row8 col0" >2.675439</td>
#       <td id="T_19e2e_row8_col1" class="data row8 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row9" class="row_heading level0 row9" >Danny Ings</th>
#       <td id="T_19e2e_row9_col0" class="data row9 col0" >2.526316</td>
#       <td id="T_19e2e_row9_col1" class="data row9 col1" >114</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row10" class="row_heading level0 row10" >Darwin Núñez Ribeiro</th>
#       <td id="T_19e2e_row10_col0" class="data row10 col0" >2.421053</td>
#       <td id="T_19e2e_row10_col1" class="data row10 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row11" class="row_heading level0 row11" >Alexander Isak</th>
#       <td id="T_19e2e_row11_col0" class="data row11 col0" >2.342857</td>
#       <td id="T_19e2e_row11_col1" class="data row11 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_19e2e_level0_row12" class="row_heading level0 row12" >Julián Álvarez</th>
#       <td id="T_19e2e_row12_col0" class="data row12 col0" >2.342105</td>
#       <td id="T_19e2e_row12_co

# %% [markdown]
# Overall, there is a large amount of overlap between the 3 methods. Of note, the following players that ranked highly in Method 1 (highest mean score regardless of position played) that were then dropped after the points remap were:
# * Yoane Wissa (replaced By Chris Wood)
#
# As Chris Wood also appears in Method 2 (i.e. he was actually playing as a Forward), I am happy to take the 15 players as ranked by Method 3 and continue the analysis.

# %%
top_15_FWDs = list(method_3_results.index)
top_15_FWDs
# Out:
# ['Erling Haaland',
#  'Harry Kane',
#  'Ollie Watkins',
#  'Ivan Toney',
#  'Cody Gakpo',
#  'Dominic Solanke',
#  'Daniel Jebbison',
#  'Gabriel Fernando de Jesus',
#  'Callum Wilson',
#  'Michail Antonio',
#  'Danny Ings',
#  'Darwin Núñez Ribeiro',
#  'Alexander Isak',
#  'Julián Álvarez',
#  'Chris Wood']

# %% [markdown]
# # What's their performance like this season so far?
#
# ## Preprocessing before analysis:
#
# First let's rename and reorder columns, then calculate standard deviation of total - bonus points.

# %%
method_3_results.rename(columns={'total - bonus points':'mean total - bonus 2020 - 2023','GWs played': 'GWs played 2020-2023'}, inplace = True)
method_3_results = method_3_results[['GWs played 2020-2023', 'mean total - bonus 2020 - 2023']]
# Standard deviation of remapped points:
pts_std = Remap_FWDs_2020_2023.loc[:,['name','total - bonus points']].groupby(['name']).std()
pts_std.rename(columns = {'total - bonus points':'Std total - bonus 2020 - 2023'},inplace = True)
method_3_results = method_3_results.join(pts_std, how='left')
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Harry Kane                                  114
# Ollie Watkins                               114
# Ivan Toney                                   76
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Harry Kane                                       5.140351
# Ollie Watkins                                    3.631579
# Ivan Toney                                       3.513158
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023
# name
# Erling Haaland                                  4.554709
# Harry Kane                                      3.594187
# Ollie Watkins                                   2.851061
# Ivan Toney                                      3.259830
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507

# %% [markdown]
# ## Join 2023/24 season data:

# %%
mean_pts_2023_24 = data_2023_24.loc[data_2023_24.name.isin(top_15_FWDs),['name','total - bonus points']].groupby(['name']).mean()
mean_pts_2023_24.rename(columns={'total - bonus points':'mean total - bonus 2023-24'}, inplace = True)
method_3_results = method_3_results.join(mean_pts_2023_24, how = 'left')
method_3_results.drop(labels=['Harry Kane', 'Ivan Toney'], inplace = True)
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  \
# name
# Erling Haaland                                  4.554709
# Ollie Watkins                                   2.851061
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507
#
#                            mean total - bonus 2023-24
# name
# Erling Haaland                                   8.25
# Ollie Watkins                                    4.25
# Cody Gakpo                                       1.50
# Dominic Solanke                                  4.75
# Daniel Jebbison                                  0.00
# Gabriel Fernando de Jesus                        1.25
# Callum Wilson                                    3.00
# Michail Antonio                                  3.75
# Danny Ings                                       0.75
# Darwin Núñez Ribeiro                             4.50
# Alexander Isak                                   4.00
# Julián Álvarez                                   6.00
# Chris Wood                                       2.00

# %% [markdown]
# ## Statistical Test
#
# We want to see if there's a statistically significant difference in the performance of these players this season (so far). That is, we want to say with a 95% confidence that there is an effect present in the data causing the change in performance. We cannot say what this effect is - i.e. is it because these players have played a sequence of easy or hard teams so far? Are they playing out of position? We can only say that an effect exists, and we will factor this into our eventual drafting decisions.
#
# To this end:
# * We will calculate the effect size - this shows how large the deviation in performance is this season compared to the last 3 seasons.
# * We will carry out a 1-sided t-test for the mean total - bonus points. We consider the 3 previous seasons from 2020/21 - 2022/23 to be our population data: we have all the data from these seasons, not just a sample of a handful of games. We will compare this to our "sample" this season: the GWs that have been played so far. A 1-sided test will be used because we care about the "direction" of the change, i.e. we care not just that it changed, but did it increase or decrease?
# * We will then use the Benjamini-Hochberg procedure to limit the False Discovery Rate (FDR) to 5% - as we are carrying out ~15 tests, we want to be sure we're not measuring an effect due to sampling chance.
#
# ### Effect Size
#
# We will use Cohen's d to measure effect size.

# %%
method_3_results['Effect size'] = (method_3_results['mean total - bonus 2023-24'] - \
                                   method_3_results['mean total - bonus 2020 - 2023'])\
                                    /method_3_results['Std total - bonus 2020 - 2023']
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  \
# name
# Erling Haaland                                  4.554709
# Ollie Watkins                                   2.851061
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507
#
#                            mean total - bonus 2023-24  Effect size
# name
# Erling Haaland                                   8.25     0.470883
# Ollie Watkins                                    4.25     0.216909
# Cody Gakpo                                       1.50    -0.641351
# Dominic Solanke                                  4.75     0.596201
# Daniel Jebbison                                  0.00    -1.240216
# Gabriel Fernando de Jesus                        1.25    -0.445732
# Callum Wilson                                    3.00     0.083175
# Michail Antonio                                  3.75     0.419062
# Danny Ings                                       0.75    -0.652900
# Darwin Núñez Ribeiro                             4.50     0.733456
# Alexander Isak                                   4.00     0.592587
# Julián Álvarez                                   6.00     1.266682
# Chris Wood                                       2.00    -0.102127

# %% [markdown]
# ### 1-sided t-test
#
# $H_0$ $:$ mean points 2023/24 season - mean points 2020/21 - 2022/23 = 0
#
# $H_A$ $:$ mean points 2023/24 season > mean points 2020/21 - 2022/23 **OR** mean points 2023/24 season < mean points 2020/21 - 2022/23
# (depending on the change)

# %%
method_3_results['n'] = len(data_2023_24['GW'].unique()) # Sample size
method_3_results['SE'] = method_3_results['Std total - bonus 2020 - 2023']/np.sqrt(method_3_results['n'])
method_3_results['t'] = (method_3_results['mean total - bonus 2023-24'] - \
                        method_3_results['mean total - bonus 2020 - 2023'])/method_3_results['SE']
method_3_results['p-value'] = t.sf(np.abs(method_3_results['t'].values), method_3_results['n'].values-1)
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  \
# name
# Erling Haaland                                  4.554709
# Ollie Watkins                                   2.851061
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507
#
#                            mean total - bonus 2023-24  Effect size  n  \
# name
# Erling Haaland                                   8.25     0.470883  4
# Ollie Watkins                                    4.25     0.216909  4
# Cody Gakpo                                       1.50    -0.641351  4
# Dominic Solanke                                  4.75     0.596201  4
# Daniel Jebbison                                  0.00    -1.240216  4
# Gabriel Fernando de Jesus                        1.25    -0.445732  4
# Callum Wilson                                    3.00     0.083175  4
# Michail Antonio                                  3.75     0.419062  4
# Danny Ings                                       0.75    -0.652900  4
# Darwin Núñez Ribeiro                             4.50     0.733456  4
# Alexander Isak                                   4.00     0.592587  4
# Julián Álvarez                                   6.00     1.266682  4
# Chris Wood                                       2.00    -0.102127  4
#
#                                  SE         t   p-value
# name
# Erling Haaland             2.277355  0.941767  0.207895
# Ollie Watkins              1.425531  0.433818  0.346862
# Cody Gakpo                 1.417462 -1.282702  0.144860
# Dominic Solanke            1.423487  1.192402  0.159411
# Daniel Jebbison            1.108678 -2.480432  0.044618
# Gabriel Fernando de Jesus  1.658026 -0.891464  0.219179
# Callum Wilson              1.687419  0.166350  0.439231
# Michail Antonio            1.282102  0.838125  0.231740
# Danny Ings                 1.360327 -1.305801  0.141364
# Darwin Núñez Ribeiro       1.417228  1.466911  0.119339
# Alexander Isak             1.398228  1.185173  0.160639
# Julián Álvarez             1.443889  2.533363  0.042586
# Chris Wood                 1.180253 -0.204254  0.425613

# %% [markdown]
# ### Benjamini-Hochberg Procedure
#
# Control the false discovery rate (FDR) to 5%. We will not record the new p-values - just whether the null hypothesis is rejected or not i.e. whether the result is statistically significant.

# %%
method_3_results['BH Statistically Significant'], _, _, _ = multipletests(method_3_results['p-value'].values, 
                                                                alpha=0.05, 
                                                                method='fdr_bh',
                                                                is_sorted=False, 
                                                                returnsorted=False)
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  \
# name
# Erling Haaland                                  4.554709
# Ollie Watkins                                   2.851061
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507
#
#                            mean total - bonus 2023-24  Effect size  n  \
# name
# Erling Haaland                                   8.25     0.470883  4
# Ollie Watkins                                    4.25     0.216909  4
# Cody Gakpo                                       1.50    -0.641351  4
# Dominic Solanke                                  4.75     0.596201  4
# Daniel Jebbison                                  0.00    -1.240216  4
# Gabriel Fernando de Jesus                        1.25    -0.445732  4
# Callum Wilson                                    3.00     0.083175  4
# Michail Antonio                                  3.75     0.419062  4
# Danny Ings                                       0.75    -0.652900  4
# Darwin Núñez Ribeiro                             4.50     0.733456  4
# Alexander Isak                                   4.00     0.592587  4
# Julián Álvarez                                   6.00     1.266682  4
# Chris Wood                                       2.00    -0.102127  4
#
#                                  SE         t   p-value  \
# name
# Erling Haaland             2.277355  0.941767  0.207895
# Ollie Watkins              1.425531  0.433818  0.346862
# Cody Gakpo                 1.417462 -1.282702  0.144860
# Dominic Solanke            1.423487  1.192402  0.159411
# Daniel Jebbison            1.108678 -2.480432  0.044618
# Gabriel Fernando de Jesus  1.658026 -0.891464  0.219179
# Callum Wilson              1.687419  0.166350  0.439231
# Michail Antonio            1.282102  0.838125  0.231740
# Danny Ings                 1.360327 -1.305801  0.141364
# Darwin Núñez Ribeiro       1.417228  1.466911  0.119339
# Alexander Isak             1.398228  1.185173  0.160639
# Julián Álvarez             1.443889  2.533363  0.042586
# Chris Wood                 1.180253 -0.204254  0.425613
#
#                            BH Statistically Significant
# name
# Erling Haaland                                    False
# Ollie Watkins                                     False
# Cody Gakpo                                        False
# Dominic Solanke                                   False
# Daniel Jebbison                                   False
# Gabriel Fernando de Jesus                         False
# Callum Wilson                                     False
# Michail Antonio                                   False
# Danny Ings                                        False
# Darwin Núñez Ribeiro                              False
# Alexander Isak                                    False
# Julián Álvarez                                    False
# Chris Wood                                        False

# %% [markdown]
# ### Effect Size Label:

# %%
method_3_results['Effect size label'] = np.digitize(np.abs(method_3_results['Effect size']), [0.01,0.2,0.5,0.8,1.20,2.0],
                                                   right = True)
method_3_results['Effect size label'] = method_3_results['Effect size label'].map({0:'None',1:'Very small',2:'Small',
                                                                                   3:'Medium',4:'Large',5:'Very large',
                                                                                   6:'Huge'})
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  \
# name
# Erling Haaland                                  4.554709
# Ollie Watkins                                   2.851061
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507
#
#                            mean total - bonus 2023-24  Effect size  n  \
# name
# Erling Haaland                                   8.25     0.470883  4
# Ollie Watkins                                    4.25     0.216909  4
# Cody Gakpo                                       1.50    -0.641351  4
# Dominic Solanke                                  4.75     0.596201  4
# Daniel Jebbison                                  0.00    -1.240216  4
# Gabriel Fernando de Jesus                        1.25    -0.445732  4
# Callum Wilson                                    3.00     0.083175  4
# Michail Antonio                                  3.75     0.419062  4
# Danny Ings                                       0.75    -0.652900  4
# Darwin Núñez Ribeiro                             4.50     0.733456  4
# Alexander Isak                                   4.00     0.592587  4
# Julián Álvarez                                   6.00     1.266682  4
# Chris Wood                                       2.00    -0.102127  4
#
#                                  SE         t   p-value  \
# name
# Erling Haaland             2.277355  0.941767  0.207895
# Ollie Watkins              1.425531  0.433818  0.346862
# Cody Gakpo                 1.417462 -1.282702  0.144860
# Dominic Solanke            1.423487  1.192402  0.159411
# Daniel Jebbison            1.108678 -2.480432  0.044618
# Gabriel Fernando de Jesus  1.658026 -0.891464  0.219179
# Callum Wilson              1.687419  0.166350  0.439231
# Michail Antonio            1.282102  0.838125  0.231740
# Danny Ings                 1.360327 -1.305801  0.141364
# Darwin Núñez Ribeiro       1.417228  1.466911  0.119339
# Alexander Isak             1.398228  1.185173  0.160639
# Julián Álvarez             1.443889  2.533363  0.042586
# Chris Wood                 1.180253 -0.204254  0.425613
#
#                            BH Statistically Significant Effect size label
# name
# Erling Haaland                                    False             Small
# Ollie Watkins                                     False             Small
# Cody Gakpo                                        False            Medium
# Dominic Solanke                                   False            Medium
# Daniel Jebbison                                   False        Very large
# Gabriel Fernando de Jesus                         False             Small
# Callum Wilson                                     False        Very small
# Michail Antonio                                   False             Small
# Danny Ings                                        False            Medium
# Darwin Núñez Ribeiro                              False            Medium
# Alexander Isak                                    False            Medium
# Julián Álvarez                                    False        Very large
# Chris Wood                                        False        Very small

# %% [markdown]
# ### Statistical Test Conclusion
#
# We fail to reject the null hypothesis $H_0$ for all 15 players after applying the Benjamini Hochberg procedure, meaning the performance deviation of these players is not statistically significant. It may be the case for some players that their performance actually hasn't changed at all, whereas for others, it may be due to chance in the sample of games they've played so far.
#
# # Additional Stats for 2023/24 season
#
# Price, and average rank of opponent teams so far are important metrics to analyse when drafting players.
#
# ## Add price column

# %%
latest_GW = data_2023_24.GW.max()
current_price_df = data_2023_24.loc[(data_2023_24.GW == latest_GW) & (data_2023_24.name.isin(top_15_FWDs)), 
                                    ['name','value']]
current_price_df.set_index('name',inplace=True)
current_price_df.value /= 10 # get price in millions
current_price_df.rename(columns={'value':'Current Price (M)'}, inplace=True)
method_3_results = method_3_results.join(current_price_df, how='left')
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  \
# name
# Erling Haaland                                  4.554709
# Ollie Watkins                                   2.851061
# Cody Gakpo                                      2.834924
# Dominic Solanke                                 2.846974
# Daniel Jebbison                                 2.217356
# Gabriel Fernando de Jesus                       3.316051
# Callum Wilson                                   3.374839
# Michail Antonio                                 2.564204
# Danny Ings                                      2.720654
# Darwin Núñez Ribeiro                            2.834456
# Alexander Isak                                  2.796456
# Julián Álvarez                                  2.887778
# Chris Wood                                      2.360507
#
#                            mean total - bonus 2023-24  Effect size  n  \
# name
# Erling Haaland                                   8.25     0.470883  4
# Ollie Watkins                                    4.25     0.216909  4
# Cody Gakpo                                       1.50    -0.641351  4
# Dominic Solanke                                  4.75     0.596201  4
# Daniel Jebbison                                  0.00    -1.240216  4
# Gabriel Fernando de Jesus                        1.25    -0.445732  4
# Callum Wilson                                    3.00     0.083175  4
# Michail Antonio                                  3.75     0.419062  4
# Danny Ings                                       0.75    -0.652900  4
# Darwin Núñez Ribeiro                             4.50     0.733456  4
# Alexander Isak                                   4.00     0.592587  4
# Julián Álvarez                                   6.00     1.266682  4
# Chris Wood                                       2.00    -0.102127  4
#
#                                  SE         t   p-value  \
# name
# Erling Haaland             2.277355  0.941767  0.207895
# Ollie Watkins              1.425531  0.433818  0.346862
# Cody Gakpo                 1.417462 -1.282702  0.144860
# Dominic Solanke            1.423487  1.192402  0.159411
# Daniel Jebbison            1.108678 -2.480432  0.044618
# Gabriel Fernando de Jesus  1.658026 -0.891464  0.219179
# Callum Wilson              1.687419  0.166350  0.439231
# Michail Antonio            1.282102  0.838125  0.231740
# Danny Ings                 1.360327 -1.305801  0.141364
# Darwin Núñez Ribeiro       1.417228  1.466911  0.119339
# Alexander Isak             1.398228  1.185173  0.160639
# Julián Álvarez             1.443889  2.533363  0.042586
# Chris Wood                 1.180253 -0.204254  0.425613
#
#                            BH Statistically Significant Effect size label  \
# name
# Erling Haaland                                    False             Small
# Ollie Watkins                                     False             Small
# Cody Gakpo                                        False            Medium
# Dominic Solanke                                   False            Medium
# Daniel Jebbison                                   False        Very large
# Gabriel Fernando de Jesus                         False             Small
# Callum Wilson                                     False        Very small
# Michail Antonio                                   False             Small
# Danny Ings                                        False            Medium
# Darwin Núñez Ribeiro                              False            Medium
# Alexander Isak                                    False            Medium
# Julián Álvarez                                    False        Very large
# Chris Wood                                        False        Very small
#
#                            Current Price (M)
# name
# Erling Haaland                          14.0
# Ollie Watkins                            8.0
# Cody Gakpo                               7.4
# Dominic Solanke                          6.5
# Daniel Jebbison                          4.9
# Gabriel Fernando de Jesus                7.9
# Callum Wilson                            7.9
# Michail Antonio                          6.1
# Danny Ings                               5.9
# Darwin Núñez Ribeiro                     7.3
# Alexander Isak                           7.7
# Julián Álvarez                           6.6
# Chris Wood                               5.0

# %% [markdown]
# ## Add mean opposition strength column

# %%
team_data_path = '../data/Fantasy-Premier-League/data/2023-24/teams.csv'
team_data = pd.read_csv(team_data_path)
team_id_rank_map = dict(zip(team_data.id, team_data.strength)) # Create map between team id and strength

# %%
avg_team_rank = data_2023_24.loc[data_2023_24.name.isin(top_15_FWDs), ['name','opponent_team']]
avg_team_rank.opponent_team = avg_team_rank.opponent_team.map(team_id_rank_map)
avg_team_rank = avg_team_rank.groupby('name').mean()
avg_team_rank.rename(columns = {'opponent_team': 'Average opposition strength 2023/24'}, inplace=True)
method_3_results = method_3_results.join(avg_team_rank, how='left')
method_3_results.rename(columns = {'n': 'GWs played 2023-24'}, inplace=True)
method_3_results = method_3_results[['GWs played 2020-2023','mean total - bonus 2020 - 2023',
                                     'Std total - bonus 2020 - 2023',
                                     'GWs played 2023-24','mean total - bonus 2023-24',
                                     'Effect size',
                                     'SE','t','p-value','BH Statistically Significant',
                                     'Effect size label','Current Price (M)','Average opposition strength 2023/24']]
method_3_results
# Out:
#                            GWs played 2020-2023  \
# name
# Erling Haaland                               38
# Ollie Watkins                               114
# Cody Gakpo                                   22
# Dominic Solanke                              38
# Daniel Jebbison                               4
# Gabriel Fernando de Jesus                   114
# Callum Wilson                               114
# Michail Antonio                             114
# Danny Ings                                  114
# Darwin Núñez Ribeiro                         38
# Alexander Isak                               35
# Julián Álvarez                               38
# Chris Wood                                  112
#
#                            mean total - bonus 2020 - 2023  \
# name
# Erling Haaland                                   6.105263
# Ollie Watkins                                    3.631579
# Cody Gakpo                                       3.318182
# Dominic Solanke                                  3.052632
# Daniel Jebbison                                  2.750000
# Gabriel Fernando de Jesus                        2.728070
# Callum Wilson                                    2.719298
# Michail Antonio                                  2.675439
# Danny Ings                                       2.526316
# Darwin Núñez Ribeiro                             2.421053
# Alexander Isak                                   2.342857
# Julián Álvarez                                   2.342105
# Chris Wood                                       2.241071
#
#                            Std total - bonus 2020 - 2023  GWs played 2023-24  \
# name
# Erling Haaland                                  4.554709                   4
# Ollie Watkins                                   2.851061                   4
# Cody Gakpo                                      2.834924                   4
# Dominic Solanke                                 2.846974                   4
# Daniel Jebbison                                 2.217356                   4
# Gabriel Fernando de Jesus                       3.316051                   4
# Callum Wilson                                   3.374839                   4
# Michail Antonio                                 2.564204                   4
# Danny Ings                                      2.720654                   4
# Darwin Núñez Ribeiro                            2.834456                   4
# Alexander Isak                                  2.796456                   4
# Julián Álvarez                                  2.887778                   4
# Chris Wood                                      2.360507                   4
#
#                            mean total - bonus 2023-24  Effect size        SE  \
# name
# Erling Haaland                                   8.25     0.470883  2.277355
# Ollie Watkins                                    4.25     0.216909  1.425531
# Cody Gakpo                                       1.50    -0.641351  1.417462
# Dominic Solanke                                  4.75     0.596201  1.423487
# Daniel Jebbison                                  0.00    -1.240216  1.108678
# Gabriel Fernando de Jesus                        1.25    -0.445732  1.658026
# Callum Wilson                                    3.00     0.083175  1.687419
# Michail Antonio                                  3.75     0.419062  1.282102
# Danny Ings                                       0.75    -0.652900  1.360327
# Darwin Núñez Ribeiro                             4.50     0.733456  1.417228
# Alexander Isak                                   4.00     0.592587  1.398228
# Julián Álvarez                                   6.00     1.266682  1.443889
# Chris Wood                                       2.00    -0.102127  1.180253
#
#                                   t   p-value  BH Statistically Significant  \
# name
# Erling Haaland             0.941767  0.207895                         False
# Ollie Watkins              0.433818  0.346862                         False
# Cody Gakpo                -1.282702  0.144860                         False
# Dominic Solanke            1.192402  0.159411                         False
# Daniel Jebbison           -2.480432  0.044618                         False
# Gabriel Fernando de Jesus -0.891464  0.219179                         False
# Callum Wilson              0.166350  0.439231                         False
# Michail Antonio            0.838125  0.231740                         False
# Danny Ings                -1.305801  0.141364                         False
# Darwin Núñez Ribeiro       1.466911  0.119339                         False
# Alexander Isak             1.185173  0.160639                         False
# Julián Álvarez             2.533363  0.042586                         False
# Chris Wood                -0.204254  0.425613                         False
#
#                           Effect size label  Current Price (M)  \
# name
# Erling Haaland                        Small               14.0
# Ollie Watkins                         Small                8.0
# Cody Gakpo                           Medium                7.4
# Dominic Solanke                      Medium                6.5
# Daniel Jebbison                  Very large                4.9
# Gabriel Fernando de Jesus             Small                7.9
# Callum Wilson                    Very small                7.9
# Michail Antonio                       Small                6.1
# Danny Ings                           Medium                5.9
# Darwin Núñez Ribeiro                 Medium                7.3
# Alexander Isak                       Medium                7.7
# Julián Álvarez                   Very large                6.6
# Chris Wood                       Very small                5.0
#
#                            Average opposition strength 2023/24
# name
# Erling Haaland                                            2.75
# Ollie Watkins                                             3.25
# Cody Gakpo                                                3.25
# Dominic Solanke                                           3.25
# Daniel Jebbison                                           3.50
# Gabriel Fernando de Jesus                                 3.25
# Callum Wilson                                             3.75
# Michail Antonio                                           2.75
# Danny Ings                                                2.75
# Darwin Núñez Ribeiro                                      3.25
# Alexander Isak                                            3.75
# Julián Álvarez                                            2.75
# Chris Wood                                                3.25

# %% [markdown]
# # Style table

# %%
def points_change(x):
    c1 = '''color:white;background-color: forestgreen '''
    c2 = '''color:white;background-color: crimson '''
    #compare columns
    mask = x['Effect size'] > 0
    mask2 = x['Effect size'] < 0
    #DataFrame with same index and columns names as original filled empty strings
    df1 =  pd.DataFrame('', index=x.index, columns=x.columns)
    #modify values of df1 column by boolean mask
    df1.loc[mask, 'mean total - bonus 2023-24'] = c1
    df1.loc[mask2, 'mean total - bonus 2023-24'] = c2
    
    return df1

def effect_size_colour(x):
    a = sns.color_palette('BuGn',7).as_hex()
    
    none = f'''color:black;background-color: {a[0]} '''
    vsmall = f'''color:white;background-color: {a[1]} '''
    small = f'''color:white;background-color: {a[2]} '''
    med = f'''color:white;background-color: {a[3]} '''
    large = f'''color:white;background-color: {a[4]} '''
    vlarge = f'''color:white;background-color: {a[5]} '''
    huge = f'''color:white;background-color: {a[6]} '''
    #compare columns
    mask = x['Effect size label'] == 'None'
    mask2= x['Effect size label'] == 'Very small'
    mask3= x['Effect size label'] == 'Small'
    mask4= x['Effect size label'] == 'Medium'
    mask5= x['Effect size label'] == 'Large'
    mask6= x['Effect size label'] == 'Very large'
    mask7= x['Effect size label'] == 'Huge'
    #DataFrame with same index and columns names as original filled empty strings
    df1 =  pd.DataFrame('', index=x.index, columns=x.columns)
    #modify values of df1 column by boolean mask
    df1.loc[mask, 'Effect size label'] = none
    df1.loc[mask2, 'Effect size label'] = vsmall
    df1.loc[mask3, 'Effect size label'] = small
    df1.loc[mask4, 'Effect size label'] = med
    df1.loc[mask5, 'Effect size label'] = large
    df1.loc[mask6, 'Effect size label'] = vlarge
    df1.loc[mask7, 'Effect size label'] = huge
    
    return df1

# %%
highlight_slice = ['mean total - bonus 2020 - 2023','Current Price (M)']
method_3_results.style.set_properties(**{'color':'black','background-color': '#ffffb3'}, subset=highlight_slice)\
.background_gradient(cmap=sns.diverging_palette(145, 10, as_cmap=True), subset=['Average opposition strength 2023/24'])\
.applymap(lambda x: f'''color:white;background-color: {'forestgreen' if x else 'crimson'}''',subset=['BH Statistically Significant'])\
.apply(points_change, axis=None)\
.apply(effect_size_colour, axis=None)
# Out:
# C:\Users\Development\AppData\Local\Temp\ipykernel_10920\2089667799.py:4: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(lambda x: f'''color:white;background-color: {'forestgreen' if x else 'crimson'}''',subset=['BH Statistically Significant'])\
# <style type="text/css">
# #T_26fa8_row0_col1, #T_26fa8_row0_col11, #T_26fa8_row1_col1, #T_26fa8_row1_col11, #T_26fa8_row2_col1, #T_26fa8_row2_col11, #T_26fa8_row3_col1, #T_26fa8_row3_col11, #T_26fa8_row4_col1, #T_26fa8_row4_col11, #T_26fa8_row5_col1, #T_26fa8_row5_col11, #T_26fa8_row6_col1, #T_26fa8_row6_col11, #T_26fa8_row7_col1, #T_26fa8_row7_col11, #T_26fa8_row8_col1, #T_26fa8_row8_col11, #T_26fa8_row9_col1, #T_26fa8_row9_col11, #T_26fa8_row10_col1, #T_26fa8_row10_col11, #T_26fa8_row11_col1, #T_26fa8_row11_col11, #T_26fa8_row12_col1, #T_26fa8_row12_col11 {
#   color: black;
#   background-color: #ffffb3;
# }
# #T_26fa8_row0_col4, #T_26fa8_row1_col4, #T_26fa8_row3_col4, #T_26fa8_row6_col4, #T_26fa8_row7_col4, #T_26fa8_row9_col4, #T_26fa8_row10_col4, #T_26fa8_row11_col4 {
#   color: white;
#   background-color: forestgreen;
# }
# #T_26fa8_row0_col9, #T_26fa8_row1_col9, #T_26fa8_row2_col4, #T_26fa8_row2_col9, #T_26fa8_row3_col9, #T_26fa8_row4_col4, #T_26fa8_row4_col9, #T_26fa8_row5_col4, #T_26fa8_row5_col9, #T_26fa8_row6_col9, #T_26fa8_row7_col9, #T_26fa8_row8_col4, #T_26fa8_row8_col9, #T_26fa8_row9_col9, #T_26fa8_row10_col9, #T_26fa8_row11_col9, #T_26fa8_row12_col4, #T_26fa8_row12_col9 {
#   color: white;
#   background-color: crimson;
# }
# #T_26fa8_row0_col10, #T_26fa8_row1_col10, #T_26fa8_row5_col10, #T_26fa8_row7_col10 {
#   color: white;
#   background-color: #98d8c9;
# }
# #T_26fa8_row0_col12, #T_26fa8_row7_col12, #T_26fa8_row8_col12, #T_26fa8_row11_col12 {
#   background-color: #3a855e;
#   color: #f1f1f1;
# }
# #T_26fa8_row1_col12, #T_26fa8_row2_col12, #T_26fa8_row3_col12, #T_26fa8_row5_col12, #T_26fa8_row9_col12, #T_26fa8_row12_col12 {
#   background-color: #f2f1f1;
#   color: #000000;
# }
# #T_26fa8_row2_col10, #T_26fa8_row3_col10, #T_26fa8_row8_col10, #T_26fa8_row9_col10, #T_26fa8_row10_col10 {
#   color: white;
#   background-color: #65c2a3;
# }
# #T_26fa8_row4_col10, #T_26fa8_row11_col10 {
#   color: white;
#   background-color: #228a44;
# }
# #T_26fa8_row4_col12 {
#   background-color: #e6959b;
#   color: #f1f1f1;
# }
# #T_26fa8_row6_col10, #T_26fa8_row12_col10 {
#   color: white;
#   background-color: #ccece6;
# }
# #T_26fa8_row6_col12, #T_26fa8_row10_col12 {
#   background-color: #da3b46;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26fa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26fa8_level0_col0" class="col_heading level0 col0" >GWs played 2020-2023</th>
#       <th id="T_26fa8_level0_col1" class="col_heading level0 col1" >mean total - bonus 2020 - 2023</th>
#       <th id="T_26fa8_level0_col2" class="col_heading level0 col2" >Std total - bonus 2020 - 2023</th>
#       <th id="T_26fa8_level0_col3" class="col_heading level0 col3" >GWs played 2023-24</th>
#       <th id="T_26fa8_level0_col4" class="col_heading level0 col4" >mean total - bonus 2023-24</th>
#       <th id="T_26fa8_level0_col5" class="col_heading level0 col5" >Effect size</th>
#       <th id="T_26fa8_level0_col6" class="col_heading level0 col6" >SE</th>
#       <th id="T_26fa8_level0_col7" class="col_heading level0 col7" >t</th>
#       <th id="T_26fa8_level0_col8" class="col_heading level0 col8" >p-value</th>
#       <th id="T_26fa8_level0_col9" class="col_heading level0 col9" >BH Statistically Significant</th>
#       <th id="T_26fa8_level0_col10" class="col_heading level0 col10" >Effect size label</th>
#       <th id="T_26fa8_level0_col11" class="col_heading level0 col11" >Current Price (M)</th>
#       <th id="T_26fa8_level0_col12" class="col_heading level0 col12" >Average opposition strength 2023/24</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26fa8_level0_row0" class="row_heading level0 row0" >Erling Haaland</th>
#       <td id="T_26fa8_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_26fa8_row0_col1" class="data row0 col1" >6.105263</td>
#       <td id="T_26fa8_row0_col2" class="data row0 col2" >4.554709</td>
#       <td id="T_26fa8_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_26fa8_row0_col4" class="data row0 col4" >8.250000</td>
#       <td id="T_26fa8_row0_col5" class="data row0 col5" >0.470883</td>
#       <td id="T_26fa8_row0_col6" class="data row0 col6" >2.277355</td>
#       <td id="T_26fa8_row0_col7" class="data row0 col7" >0.941767</td>
#       <td id="T_26fa8_row0_col8" class="data row0 col8" >0.207895</td>
#       <td id="T_26fa8_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_26fa8_row0_col10" class="data row0 col10" >Small</td>
#       <td id="T_26fa8_row0_col11" class="data row0 col11" >14.000000</td>
#       <td id="T_26fa8_row0_col12" class="data row0 col12" >2.750000</td>
#     </tr>
#     <tr>
#       <th id="T_26fa8_level0_row1" class="row_heading level0 row1" >Ollie Watkins</th>
#       <td id="T_26fa8_row1_col0" class="data row1 col0" >114</td>
#       <td id="T_26fa8_row1_col1" class="data row1 col1" >3.631579</td>
#       <td id="T_26fa8_row1_col2" class="data row1 col2" >2.851061</td>
#       <td id="T_26fa8_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_26fa8_row1_col4" class="data row1 col4" >4.250000</td>
#       <td id="T_26fa8_row1_col5" class="data row1 col5" >0.216909</td>
#       <td id="T_26fa8_row1_col6" class="data row1 col6" >1.425531</td>
#       <td id="T_26fa8_row1_col7" class="data row1 col7" >0.433818</td>
#       <td id="T_26fa8_row1_col8" class="data row1 col8" >0.346862</td>
#       <td id="T_26fa8_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_26fa8_row1_col10" class="data row1 col10" >Small</td>
#       <td id="T_26fa8_row1_col11" class="data row1 col11" >8.000000</td>
#       <td id="T_26fa8_row1_col12" class="data row1 col12" >3.250000</td>
#     </tr>
#     <tr>
#       <th id="T_26fa8_level0_row2" class="row_heading level0 row2" >Cody Gakpo</th>
#       <td id="T_26fa8_row2_col0" class="data row2 col0" >22</td>
#       <td id="T_26fa8_row2_col1" class="data row2 col1" >3.318182</td>
#       <td id="T_26fa8_row2_col2" class="data row2 col2" >2.834924</td>
#       <td id="T_26fa8_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_26fa8_row2_col4" class="data row2 col4" >1.500000</td>
#       <td id="T_26fa8_row2_col5" class="data row2 col5" >-0.641351</td>
#       <td id="T_26fa8_row2_col6" class="data row2 col6" >1.417462</td>
#       <td id="T_26fa8_row2_col7" class="data row2 col7" >-1.282702</td>
#       <td id="T_26fa8_row2_col8" class="data row2 col8" >0.144860</td>
#       <td id="T_26fa8_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_26fa8_row2_col10" class="data row2 col10" >Medium</td>
#       <td id="T_26fa8_row2_col11" class="data row2 col11" >7.400000</td>
#       <td id="T_26fa8_row2_col12" class="data row2 col12" >3.250000</td>
#     </tr>
#     <tr>
#       <th id="T_26fa8_level0_row3" class="row_heading level0 row3" >Dominic Solanke</th>
#       <td id="T_26fa8_row3_col0" class="data row3 col0" >38</td>
#       <td id="T_26fa8_row3_col1" class="data row3 col1" >3.052632</td>
#       <td id="T_26fa8_row3_col2" class="data row3 col2" >2.846974</td>
#       <td id="T_26fa8_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_26fa8_row3_col4" class="data row3 col4" >4.750000</td>
#       <td id="T_26fa8_row3_col5" class="data row3 col5" >0.596201</td>
#       <td id="T_26fa8_row3_col6" class="data row3 col6" >1.423487</td>
#       <td id="T_26fa8_row3_col7" class="data row3 col7" >1.192402</td>
#       <td id="T_26fa8_row3_col8" class="data row3 col8" >0.159411</td>
#       <td id="T_26fa8_row3_col9" class="data row3 col9" >False</td>
#       <td id="T_26fa8_row3_c

# %%
highlight_slice = ['mean total - bonus 2020 - 2023','Current Price (M)']
method_3_results.style.set_properties(**{'color':'black','background-color': '#ffffb3'}, subset=highlight_slice)\
.background_gradient(cmap=sns.diverging_palette(145, 10, as_cmap=True), subset=['Average opposition strength 2023/24'])\
.applymap(lambda x: f'''color:white;background-color: {'forestgreen' if x else 'crimson'}''',subset=['BH Statistically Significant'])\
.apply(points_change, axis=None)\
.apply(effect_size_colour, axis=None).to_excel('./results/Forwards_analysis.xlsx', engine='openpyxl')
# Out:
# C:\Users\Development\AppData\Local\Temp\ipykernel_10920\1317252866.py:4: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   .applymap(lambda x: f'''color:white;background-color: {'forestgreen' if x else 'crimson'}''',subset=['BH Statistically Significant'])\

# %% [markdown]
# # Summary and Conclusion
#
# We analysed the top 15 forwards from the past 3 seasons (2020/21 - 2022/23) using 3 methods:
# * The naive approach, where we looked at their mean points regardless of the position they played when they were earned.
# * The strict approach, where we looked at their mean points only if they were playing as a forward when they were earned.
# * The points remap approach, where we looked at the mean points they would've scored if they were playing as a forward.
# The results for all 3 methods were almost identical besides one player, Yoanne Wissa, who didnt score highly when his points were mapped to that of a forward's.
#
# We then took these top 15, and compared their performance so far this season (2023/24). We calculated the effect size, to measure how big the deviation is, and then carried out a 1 sided t-test to determine if the deviation is statistically significant. After applying the Benjamini Hochberg procedure to control the FDR to 5%, we found that the differences were not statistically significant for any player.
#
# Finally, we added some information on the current price of the players and their average opposition rank this season (which may help explain performance deviations), before styling the results table and exporting to Excel.
#
# I intend to use these results, as well as the results for the other positions to compile my team after playing the wild card chip.
